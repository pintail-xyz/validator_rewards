# %% [markdown]
# # Plan
# * Compare naive aggregate stats to the model
#   * Present the final form of the model again
#   * do assumptions check on this
#   * consider the impact of slashed validators on this figure
# * Do a more detailed breakdown of aggregate stats (look at inclusion, target, head, delay individually)
# * Do this on a per validator basis - allow any validator to see exactly which types of failure caused them to fall short
#
# # Things to look at
# * proportion of validators with effective balance below 32 ETH
# * distribution of validator incomes
# * comparison of average validator reward with the expected case from the model
# * per-validator breakdown explaining why they fell short of the maximum possible (missed attestations, missed proposals, incorrect target/head, delayed inclusion)
# * per-validator stats (longest outage, longest streak, uptime, proposal opportunities (how lucky?), proportion of successful proposals, inclusion delays (delay due to missed block versus not included in block - how lucky? how many validators have not produced a single attestation or appear to have been abandoned?)
# * Does the distribution of block proposal opportunities match the binomial as expected?
#
# # To do
# * add a date x-axis to all charts with epoch or slot numbers

# %%
# imports, constants

import time

import psycopg2
import matplotlib.pyplot as plt
import pandas as pd

FAR_FUTURE_EPOCH = 2**64 - 1 # as defined in spec

# %%
# open/restart connection to chaind database

try:
    cursor.close()
    connection.close()
except:
    pass

connection = psycopg2.connect(user="chain", host="127.0.0.1", database="chain", password="medalla")
cursor = connection.cursor()

# %%
# define progress indicator function

def print_progress(start_time, current_item, n_items):
    seconds = time.time() - start_time
    elapsed = time.strftime("%H:%M:%S",time.gmtime(seconds))
    left = time.strftime("%H:%M:%S",time.gmtime(seconds * ((n_items) / (current_item+1)-1)))
    perc = 100*(current_item+1)/n_items
    print(f"iteration {current_item} of {n_items} ({perc:.2f}%) / {elapsed} elapsed / {left} left", end='\r')

# %%
# get validator and epoch summary data

cursor.execute("SELECT f_activation_eligibility_epoch, f_activation_epoch, f_exit_epoch, "
               "f_slashed, f_public_key FROM t_validators ORDER BY f_index")
result = cursor.fetchall()
validators = [{
    "index"                       : i,
    "activation_eligibility_epoch": r[0],
    "activation_epoch"            : r[1],
    "exit_epoch"                  : r[2],
    "slashed"                     : r[3],
    "slashed_slot"                : None,
    "slashed_type"                : None,
    "pubkey"                      : r[4].hex()
} for i, r in enumerate(result)]

pubkey_lookup = {r[4].hex(): validators[i] for i, r in enumerate(result)}

for v in validators:
    if v["activation_epoch"] is None:
        v["activation_epoch"] = FAR_FUTURE_EPOCH
    if v["exit_epoch"] is None:
        v["exit_epoch"] = FAR_FUTURE_EPOCH

cursor.execute("SELECT * FROM t_epoch_summaries WHERE f_epoch < 32002 ORDER BY f_epoch")
result = cursor.fetchall()
epoch_summaries = [{
    "epoch"                           : r[0],
    "activation_queue_length"         : r[1],
    "activating_validators"           : r[2],
    "active_validators"               : r[3],
    "active_real_balance"             : r[4],
    "active_balance"                  : r[5],
    "attesting_validators"            : r[6],
    "attesting_balance"               : r[7],
    "target_correct_validators"       : r[8],
    "target_correct_balance"          : r[9],
    "head_correct_validators"         : r[10],
    "head_correct_balance"            : r[11],
    "attestations_for_epoch"          : r[12],
    "attestations_in_epoch"           : r[13],
    "duplicate_attestations_for_epoch": r[14],
    "proposer_slashings"              : r[15],
    "attester_slashings"              : r[16],
    "deposits"                        : r[17],
    "exiting_validators"              : r[18],
    "canonical_blocks"                : r[19]
} for r in result]

# %%
# check for any instances of validator deposits made to already active validators

cursor.execute("SELECT f_inclusion_slot, f_validator_pubkey, f_amount FROM t_deposits")
deposits = cursor.fetchall()

repeat_deposit_count = 0
repeat_deposit_epochs = {}
for deposit in deposits:
    slot, tmp, amount = deposit
    pubkey = tmp.hex()
    if pubkey not in pubkey_lookup:
        continue
    else:
        validator = pubkey_lookup[deposit[1].hex()]
    if slot // 32 > validator["activation_epoch"]:
        repeat_deposit_count += 1
        epoch = (slot - 1) // 32 + 1 # NB chaind balances are based on the state *after* processing slot 0
        #print(f"validator {validator['index']} made duplicate deposit of {amount} in epoch {epoch}")
        cursor.execute(f"SELECT f_epoch, f_balance FROM t_validator_balances "
                       f"WHERE f_epoch BETWEEN {epoch-1} AND {epoch+1} "
                       f"AND f_validator_index = {validator['index']}")
        balances = cursor.fetchall()
        #for row in balances:
        #    print(f"epoch: {row[0]}, balance: {row[1]}")
            
        if epoch in repeat_deposit_epochs:
            repeat_deposit_epochs[epoch] += deposit[2]
        else:
            repeat_deposit_epochs[epoch] = deposit[2]

print(f"{repeat_deposit_count} repeat deposits found")
# Out:
# 5 repeat deposits found

# %%
# create a dict of slashing events, identifying slashed validator, inclusion slot and slashing type

cursor.execute("SELECT f_inclusion_slot, f_header_1_proposer_index FROM t_proposer_slashings")
proposer_slashings = cursor.fetchall()

combined = []

for slashing in proposer_slashings:
    validators[slashing[1]]["slashed_slot"] = slashing[0]
    validators[slashing[1]]["slashed_type"] = "proposer"
    combined += [[slashing[0], slashing[1], "proposer"]]

cursor.execute("SELECT f_inclusion_slot, f_attestation_1_indices, f_attestation_2_indices "
               " FROM t_attester_slashings")
attester_slashings = cursor.fetchall()
for slashing in attester_slashings:
    for index in slashing[1]:
        if index in slashing[2]:
            validators[index]["slashed_slot"] = slashing[0]
            validators[index]["slashed_type"] = "attester"
            combined += [[slashing[0], index, "attester"]]

print(f"{len(combined)} slashing events found")
#l = sorted(combined, key = lambda k: k[0])
#for s in combined:
#    print(s)
# Out:
# 135 slashing events found

# %%
for event in combined:
    epoch = event[0] // 32
    cursor.execute(f"SELECT f_balance FROM t_validator_balances "
                   f"WHERE f_validator_index = {event[1]} AND f_epoch BETWEEN {epoch-2} AND {epoch+2}")
    balances = [b[0] for b in cursor.fetchall()]
    print(f"validator {event[1]} {event[2]} violation at slot {event[0]} (epoch {epoch}.{event[0] % 32})")
    for i, balance in enumerate(balances):
        print(f"epoch {epoch-2+i}: {balance}")
# Out:
# validator 20075 proposer violation at slot 6669 (epoch 208.13)
# epoch 206: 32014788155
# epoch 207: 32014860472
# epoch 208: 32014933849
# epoch 209: 31764875586
# epoch 210: 31766407014
# validator 18177 proposer violation at slot 22374 (epoch 699.6)
# epoch 697: 32049805699
# epoch 698: 32049876895
# epoch 699: 32049948103
# epoch 700: 31799892297
# epoch 701: 31801547694
# validator 25645 proposer violation at slot 40772 (epoch 1274.4)
# epoch 1272: 32005449786
# epoch 1273: 32005517920
# epoch 1274: 32005586091
# epoch 1275: 31755532811
# epoch 1276: 31757261394
# validator 38069 proposer violation at slot 138164 (epoch 4317.20)
# epoch 4315: 32000913350
# epoch 4316: 32000969250
# epoch 4317: 32001025538
# epoch 4318: 31750981570
# epoch 4319: 31753109171
# validator 38089 proposer violation at slot 138731 (epoch 4335.11)
# epoch 4333: 32001741954
# epoch 4334: 32001798291
# epoch 4335: 32001854532
# epoch 4336: 31751819753
# epoch 4337: 31753937057
# validator 38130 proposer violation at slot 140313 (epoch 4384.25)
# epoch 4382: 32003570192
# epoch 4383: 32003625932
# epoch 4384: 32003682101
# epoch 4385: 31753638283
# epoch 4386: 31755808193
# validator 38129 proposer violation at slot 140559 (epoch 4392.15)
# epoch 4390: 32004147407
# epoch 4391: 32004203551
# epoch 4392: 32004258450
# epoch 4393: 31754227425
# epoch 4394: 31756310412
# validator 38065 proposer violation at slot 140811 (epoch 4400.11)
# epoch 4398: 32005098187
# epoch 4399: 32005153410
# epoch 4400: 32005208598
# epoch 4401: 31755164816
# epoch 4402: 31757302541
# validator 38128 proposer violation at slot 140845 (epoch 4401.13)
# epoch 4399: 32004515272
# epoch 4400: 32004570460
# epoch 4401: 32004625707
# epoch 4402: 31754583752
# epoch 4403: 31756717832
# validator 38117 proposer violation at slot 140895 (epoch 4402.31)
# epoch 4400: 32004873372
# epoch 4401: 32004928619
# epoch 4402: 32004984600
# epoch 4403: 31754940824
# epoch 4404: 31757105912
# validator 38114 proposer violation at slot 141175 (epoch 4411.23)
# epoch 4409: 32004903099
# epoch 4410: 32004959173
# epoch 4411: 32005015290
# epoch 4412: 31754973355
# epoch 4413: 31757113551
# validator 45871 proposer violation at slot 248186 (epoch 7755.26)
# epoch 7753: 32073952746
# epoch 7754: 32074001145
# epoch 7755: 32074049559
# epoch 7756: 31824011858
# epoch 7757: 31826495531
# validator 40892 proposer violation at slot 343133 (epoch 10722.29)
# epoch 10720: 32281391372
# epoch 10721: 32281434778
# epoch 10722: 32281478246
# epoch 10723: 32031444235
# epoch 10724: 32034163368
# validator 63338 proposer violation at slot 476904 (epoch 14903.8)
# epoch 14901: 32171928616
# epoch 14902: 32171962660
# epoch 14903: 32172000770
# epoch 14904: 31921970482
# epoch 14905: 31925032094
# validator 21574 attester violation at slot 17112 (epoch 534.24)
# epoch 532: 32026621529
# epoch 533: 32026693305
# epoch 534: 32026765103
# epoch 535: 31776708514
# epoch 536: 31776651931
# validator 4259 attester violation at slot 17112 (epoch 534.24)
# epoch 532: 32035798469
# epoch 533: 32035870245
# epoch 534: 32035942043
# epoch 535: 31785885454
# epoch 536: 31785828871
# validator 4100 attester violation at slot 17184 (epoch 537.0)
# epoch 535: 32034933672
# epoch 536: 32034877089
# epoch 537: 31784948878
# epoch 538: 31784892304
# epoch 539: 31784835736
# validator 4390 attester violation at slot 17184 (epoch 537.0)
# epoch 535: 32035372617
# epoch 536: 32035316034
# epoch 537: 31785387823
# epoch 538: 31785331249
# epoch 539: 31785274681
# validator 4086 attester violation at slot 17188 (epoch 537.4)
# epoch 535: 32033656776
# epoch 536: 32033600193
# epoch 537: 32033671982
# epoch 538: 31783615408
# epoch 539: 31783558840
# validator 4102 attester violation at slot 17188 (epoch 537.4)
# epoch 535: 32033727686
# epoch 536: 32033671103
# epoch 537: 32033742892
# epoch 538: 31783686318
# epoch 539: 31783629750
# validator 4110 attester violation at slot 17206 (epoch 537.22)
# epoch 535: 32033105098
# epoch 536: 32033048515
# epoch 537: 32033120304
# epoch 538: 31783063730
# epoch 539: 31783007162
# validator 13869 attester violation at slot 17206 (epoch 537.22)
# epoch 535: 32034497947
# epoch 536: 32034441364
# epoch 537: 32034513153
# epoch 538: 31784456579
# epoch 539: 31784400011
# validator 18249 attester violation at slot 17227 (epoch 538.11)
# epoch 536: 32034353726
# epoch 537: 32034425515
# epoch 538: 32034368941
# epoch 539: 31784312373
# epoch 540: 31784255805
# validator 4451 attester violation at slot 17227 (epoch 538.11)
# epoch 536: 32033406241
# epoch 537: 32033478030
# epoch 538: 32033421456
# epoch 539: 31783364888
# epoch 540: 31783308320
# validator 7635 attester violation at slot 43920 (epoch 1372.16)
# epoch 1370: 32094742967
# epoch 1371: 32094810109
# epoch 1372: 32094877323
# epoch 1373: 31844824439
# epoch 1374: 31844771561
# validator 1644 attester violation at slot 102389 (epoch 3199.21)
# epoch 3197: 32213900109
# epoch 3198: 32213959146
# epoch 3199: 32214018574
# epoch 3200: 31963971780
# epoch 3201: 31963924989
# validator 23241 attester violation at slot 118136 (epoch 3691.24)
# epoch 3689: 32150546127
# epoch 3690: 32150603062
# epoch 3691: 32150660722
# epoch 3692: 31900615236
# epoch 3693: 31900569753
# validator 38105 attester violation at slot 138194 (epoch 4318.18)
# epoch 4316: 32000562726
# epoch 4317: 32000619014
# epoch 4318: 32000675375
# epoch 4319: 31750631410
# epoch 4320: 31750587448
# validator 38061 attester violation at slot 138194 (epoch 4318.18)
# epoch 4316: 32001075048
# epoch 4317: 32001131336
# epoch 4318: 32001087368
# epoch 4319: 31751043403
# epoch 4320: 31750999441
# validator 38061 attester violation at slot 138221 (epoch 4319.13)
# epoch 4317: 32001131336
# epoch 4318: 32001087368
# epoch 4319: 31751043403
# epoch 4320: 31750999441
# epoch 4321: 31750955482
# validator 38113 attester violation at slot 138221 (epoch 4319.13)
# epoch 4317: 32000506507
# epoch 4318: 32000562868
# epoch 4319: 32000590053
# epoch 4320: 31750546091
# epoch 4321: 31750502132
# validator 38091 attester violation at slot 138770 (epoch 4336.18)
# epoch 4334: 32001713387
# epoch 4335: 32001769628
# epoch 4336: 32001825431
# epoch 4337: 31751781505
# epoch 4338: 31751737582
# validator 38148 attester violation at slot 140924 (epoch 4403.28)
# epoch 4401: 32004479677
# epoch 4402: 32004535658
# epoch 4403: 32004591204
# epoch 4404: 31754547428
# epoch 4405: 31754503655
# validator 38106 attester violation at slot 140924 (epoch 4403.28)
# epoch 4401: 32004866960
# epoch 4402: 32004922941
# epoch 4403: 32004978487
# epoch 4404: 31754934711
# epoch 4405: 31754890938
# validator 38058 attester violation at slot 161508 (epoch 5047.4)
# epoch 5045: 32025857028
# epoch 5046: 32025814641
# epoch 5047: 32025868819
# epoch 5048: 31775826438
# epoch 5049: 31775784057
# validator 38116 attester violation at slot 161508 (epoch 5047.4)
# epoch 5045: 32024570151
# epoch 5046: 32024624016
# epoch 5047: 32024678194
# epoch 5048: 31774635813
# epoch 5049: 31774593432
# validator 14415 attester violation at slot 457006 (epoch 14281.14)
# epoch 14279: 32701615687
# epoch 14280: 32701584937
# epoch 14281: 32701554187
# epoch 14282: 32451523437
# epoch 14283: 32451492687
# validator 71603 attester violation at slot 457556 (epoch 14298.20)
# epoch 14296: 32061655212
# epoch 14297: 32061653577
# epoch 14298: 32061672100
# epoch 14299: 31811641362
# epoch 14300: 31811610624
# validator 43843 attester violation at slot 231183 (epoch 7224.15)
# epoch 7222: 32071013759
# epoch 7223: 32071063213
# epoch 7224: 32071081483
# epoch 7225: 31821042987
# epoch 7226: 31821004494
# validator 38038 attester violation at slot 357060 (epoch 11158.4)
# epoch 11156: 32347415568
# epoch 11157: 32347458140
# epoch 11158: 32347500726
# epoch 11159: 32097467171
# epoch 11160: 32097433619
# validator 52866 attester violation at slot 256812 (epoch 8025.12)
# epoch 8023: 32001285192
# epoch 8024: 32001332644
# epoch 8025: 32001380509
# epoch 8026: 31751343195
# epoch 8027: 31751305884
# validator 57976 attester violation at slot 296756 (epoch 9273.20)
# epoch 9271: 32000000000
# epoch 9272: 32000000000
# epoch 9273: 32000000000
# epoch 9274: 31749964330
# epoch 9275: 31749929776
# validator 9143 attester violation at slot 421395 (epoch 13168.19)
# epoch 13166: 32492934559
# epoch 13167: 32492974606
# epoch 13168: 32493015294
# epoch 13169: 32242983626
# epoch 13170: 32242951961
# validator 8320 attester violation at slot 456892 (epoch 14277.28)
# epoch 14275: 32692257001
# epoch 14276: 32692255539
# epoch 14277: 32692224786
# epoch 14278: 32442194033
# epoch 14279: 32442163280
# validator 8275 attester violation at slot 456894 (epoch 14277.30)
# epoch 14275: 32690514646
# epoch 14276: 32690513184
# epoch 14277: 32690531949
# epoch 14278: 32440501196
# epoch 14279: 32440470443
# validator 8250 attester violation at slot 456895 (epoch 14277.31)
# epoch 14275: 32685642021
# epoch 14276: 32685640559
# epoch 14277: 32685652596
# epoch 14278: 32435621843
# epoch 14279: 32435591090
# validator 8239 attester violation at slot 456896 (epoch 14278.0)
# epoch 14276: 32674201731
# epoch 14277: 32674220496
# epoch 14278: 32424189743
# epoch 14279: 32424158990
# epoch 14280: 32424128240
# validator 16509 attester violation at slot 456945 (epoch 14279.17)
# epoch 14277: 32696185488
# epoch 14278: 32696154735
# epoch 14279: 32696123982
# epoch 14280: 32446093232
# epoch 14281: 32446062482
# validator 16491 attester violation at slot 456949 (epoch 14279.21)
# epoch 14277: 32708635679
# epoch 14278: 32708604926
# epoch 14279: 32708574173
# epoch 14280: 32458543423
# epoch 14281: 32458512673
# validator 16523 attester violation at slot 456958 (epoch 14279.30)
# epoch 14277: 32693755788
# epoch 14278: 32693725035
# epoch 14279: 32693694282
# epoch 14280: 32443663532
# epoch 14281: 32443632782
# validator 16479 attester violation at slot 456959 (epoch 14279.31)
# epoch 14277: 32699739695
# epoch 14278: 32699708942
# epoch 14279: 32699678189
# epoch 14280: 32449647439
# epoch 14281: 32449616689
# validator 17377 attester violation at slot 457452 (epoch 14295.12)
# epoch 14293: 32695429408
# epoch 14294: 32695467956
# epoch 14295: 32695437215
# epoch 14296: 32445406474
# epoch 14297: 32445375736
# validator 71676 attester violation at slot 457549 (epoch 14298.13)
# epoch 14296: 32061411583
# epoch 14297: 32061409948
# epoch 14298: 32061423988
# epoch 14299: 31811393250
# epoch 14300: 31811362512
# validator 71654 attester violation at slot 457549 (epoch 14298.13)
# epoch 14296: 32064064556
# epoch 14297: 32064062921
# epoch 14298: 32064075466
# epoch 14299: 31814044728
# epoch 14300: 31814013990
# validator 69812 attester violation at slot 457551 (epoch 14298.15)
# epoch 14296: 32082466972
# epoch 14297: 32082465337
# epoch 14298: 32082434599
# epoch 14299: 31832403861
# epoch 14300: 31832373123
# validator 71401 attester violation at slot 457551 (epoch 14298.15)
# epoch 14296: 32067464985
# epoch 14297: 32067463350
# epoch 14298: 32067481873
# epoch 14299: 31817451135
# epoch 14300: 31817420397
# validator 69884 attester violation at slot 457552 (epoch 14298.16)
# epoch 14296: 32083076803
# epoch 14297: 32083075168
# epoch 14298: 32083089208
# epoch 14299: 31833058470
# epoch 14300: 31833027732
# validator 71665 attester violation at slot 457552 (epoch 14298.16)
# epoch 14296: 32061460836
# epoch 14297: 32061453223
# epoch 14298: 32061471746
# epoch 14299: 31811441008
# epoch 14300: 31811410270
# validator 68648 attester violation at slot 457553 (epoch 14298.17)
# epoch 14296: 32100592896
# epoch 14297: 32100591261
# epoch 14298: 32100560523
# epoch 14299: 31850529785
# epoch 14300: 31850499047
# validator 69358 attester violation at slot 457553 (epoch 14298.17)
# epoch 14296: 32088126638
# epoch 14297: 32088125003
# epoch 14298: 32088143526
# epoch 14299: 31838112788
# epoch 14300: 31838082050
# validator 69895 attester violation at slot 457554 (epoch 14298.18)
# epoch 14296: 32078881715
# epoch 14297: 32078880080
# epoch 14298: 32078898603
# epoch 14299: 31828867865
# epoch 14300: 31828837127
# validator 71614 attester violation at slot 457554 (epoch 14298.18)
# epoch 14296: 32068065135
# epoch 14297: 32068063500
# epoch 14298: 32068082023
# epoch 14299: 31818051285
# epoch 14300: 31818020547
# validator 75715 attester violation at slot 457555 (epoch 14298.19)
# epoch 14296: 32021716113
# epoch 14297: 32021709995
# epoch 14298: 32021728518
# epoch 14299: 31771697780
# epoch 14300: 31771667042
# validator 71690 attester violation at slot 457555 (epoch 14298.19)
# epoch 14296: 32064769169
# epoch 14297: 32064767534
# epoch 14298: 32064781574
# epoch 14299: 31814750836
# epoch 14300: 31814720098
# validator 75162 attester violation at slot 457556 (epoch 14298.20)
# epoch 14296: 32030755035
# epoch 14297: 32030753400
# epoch 14298: 32030771923
# epoch 14299: 31780741185
# epoch 14300: 31780710447
# validator 69391 attester violation at slot 457557 (epoch 14298.21)
# epoch 14296: 32090537370
# epoch 14297: 32090535735
# epoch 14298: 32090554258
# epoch 14299: 31840523520
# epoch 14300: 31840492782
# validator 69817 attester violation at slot 457557 (epoch 14298.21)
# epoch 14296: 32082187803
# epoch 14297: 32082186168
# epoch 14298: 32082198713
# epoch 14299: 31832167975
# epoch 14300: 31832137237
# validator 69716 attester violation at slot 457558 (epoch 14298.22)
# epoch 14296: 32083301982
# epoch 14297: 32083300347
# epoch 14298: 32083318870
# epoch 14299: 31833288132
# epoch 14300: 31833257394
# validator 71664 attester violation at slot 457558 (epoch 14298.22)
# epoch 14296: 32064649946
# epoch 14297: 32064648311
# epoch 14298: 32064660109
# epoch 14299: 31814629371
# epoch 14300: 31814598633
# validator 69732 attester violation at slot 457559 (epoch 14298.23)
# epoch 14296: 32080792573
# epoch 14297: 32080784960
# epoch 14298: 32080799000
# epoch 14299: 31830768262
# epoch 14300: 31830737524
# validator 71671 attester violation at slot 457559 (epoch 14298.23)
# epoch 14296: 32067429240
# epoch 14297: 32067427605
# epoch 14298: 32067439403
# epoch 14299: 31817408665
# epoch 14300: 31817377927
# validator 69772 attester violation at slot 457560 (epoch 14298.24)
# epoch 14296: 32080716288
# epoch 14297: 32080714653
# epoch 14298: 32080733176
# epoch 14299: 31830702438
# epoch 14300: 31830671700
# validator 69841 attester violation at slot 457560 (epoch 14298.24)
# epoch 14296: 32081411121
# epoch 14297: 32081409486
# epoch 14298: 32081428009
# epoch 14299: 31831397271
# epoch 14300: 31831366533
# validator 71673 attester violation at slot 457561 (epoch 14298.25)
# epoch 14296: 32061169088
# epoch 14297: 32061161475
# epoch 14298: 32061130737
# epoch 14299: 31811099999
# epoch 14300: 31811069261
# validator 71708 attester violation at slot 457561 (epoch 14298.25)
# epoch 14296: 32064224583
# epoch 14297: 32064222948
# epoch 14298: 32064241471
# epoch 14299: 31814210733
# epoch 14300: 31814179995
# validator 69866 attester violation at slot 457562 (epoch 14298.26)
# epoch 14296: 32083208334
# epoch 14297: 32083206699
# epoch 14298: 32083225222
# epoch 14299: 31833194484
# epoch 14300: 31833163746
# validator 71699 attester violation at slot 457562 (epoch 14298.26)
# epoch 14296: 32064425691
# epoch 14297: 32064418078
# epoch 14298: 32064430623
# epoch 14299: 31814399885
# epoch 14300: 31814369147
# validator 71663 attester violation at slot 457563 (epoch 14298.27)
# epoch 14296: 32064707999
# epoch 14297: 32064706364
# epoch 14298: 32064675626
# epoch 14299: 31814644888
# epoch 14300: 31814614150
# validator 69809 attester violation at slot 457563 (epoch 14298.27)
# epoch 14296: 32078527041
# epoch 14297: 32078525406
# epoch 14298: 32078563652
# epoch 14299: 31828532914
# epoch 14300: 31828502176
# validator 69388 attester violation at slot 457564 (epoch 14298.28)
# epoch 14296: 32087238270
# epoch 14297: 32087236635
# epoch 14298: 32087205897
# epoch 14299: 31837175159
# epoch 14300: 31837144421
# validator 69756 attester violation at slot 457564 (epoch 14298.28)
# epoch 14296: 32080572171
# epoch 14297: 32080570536
# epoch 14298: 32080589059
# epoch 14299: 31830558321
# epoch 14300: 31830527583
# validator 72421 attester violation at slot 457574 (epoch 14299.6)
# epoch 14297: 32060344836
# epoch 14298: 32060363359
# epoch 14299: 32060332621
# epoch 14300: 31810301883
# epoch 14301: 31810271148
# validator 71593 attester violation at slot 457565 (epoch 14298.29)
# epoch 14296: 32064638730
# epoch 14297: 32064637095
# epoch 14298: 32064606357
# epoch 14299: 31814575619
# epoch 14300: 31814544881
# validator 71646 attester violation at slot 457565 (epoch 14298.29)
# epoch 14296: 32064911743
# epoch 14297: 32064910108
# epoch 14298: 32064879370
# epoch 14299: 31814848632
# epoch 14300: 31814817894
# validator 69786 attester violation at slot 457566 (epoch 14298.30)
# epoch 14296: 32083425808
# epoch 14297: 32083419690
# epoch 14298: 32083438213
# epoch 14299: 31833407475
# epoch 14300: 31833376737
# validator 68593 attester violation at slot 457566 (epoch 14298.30)
# epoch 14296: 32092535462
# epoch 14297: 32092529344
# epoch 14298: 32092541889
# epoch 14299: 31842511151
# epoch 14300: 31842480413
# validator 72074 attester violation at slot 457567 (epoch 14298.31)
# epoch 14296: 32060833910
# epoch 14297: 32060832275
# epoch 14298: 32060844820
# epoch 14299: 31810814082
# epoch 14300: 31810783344
# validator 72491 attester violation at slot 457575 (epoch 14299.7)
# epoch 14297: 32053227401
# epoch 14298: 32053245924
# epoch 14299: 32053215186
# epoch 14300: 31803184448
# epoch 14301: 31803153713
# validator 72499 attester violation at slot 457567 (epoch 14298.31)
# epoch 14296: 32053379007
# epoch 14297: 32053370647
# epoch 14298: 32053389170
# epoch 14299: 31803358432
# epoch 14300: 31803327694
# validator 69717 attester violation at slot 457568 (epoch 14299.0)
# epoch 14297: 32080886383
# epoch 14298: 32080924629
# epoch 14299: 31830893891
# epoch 14300: 31830863153
# epoch 14301: 31830832418
# validator 71714 attester violation at slot 457572 (epoch 14299.4)
# epoch 14297: 32061387375
# epoch 14298: 32061356637
# epoch 14299: 32061325899
# epoch 14300: 31811295161
# epoch 14301: 31811264426
# validator 70044 attester violation at slot 457568 (epoch 14299.0)
# epoch 14297: 32079577574
# epoch 14298: 32079596097
# epoch 14299: 31829565359
# epoch 14300: 31829534621
# epoch 14301: 31829503886
# validator 71672 attester violation at slot 457570 (epoch 14299.2)
# epoch 14297: 32064335736
# epoch 14298: 32064354259
# epoch 14299: 32064323521
# epoch 14300: 31814292783
# epoch 14301: 31814262048
# validator 71709 attester violation at slot 457570 (epoch 14299.2)
# epoch 14297: 32064555821
# epoch 14298: 32064525083
# epoch 14299: 32064494345
# epoch 14300: 31814463607
# epoch 14301: 31814432872
# validator 71718 attester violation at slot 457571 (epoch 14299.3)
# epoch 14297: 32063931701
# epoch 14298: 32063900963
# epoch 14299: 32063870225
# epoch 14300: 31813839487
# epoch 14301: 31813808752
# validator 72084 attester violation at slot 457571 (epoch 14299.3)
# epoch 14297: 32057380106
# epoch 14298: 32057349368
# epoch 14299: 32057318630
# epoch 14300: 31807287892
# epoch 14301: 31807257157
# validator 72674 attester violation at slot 457578 (epoch 14299.10)
# epoch 14297: 32051475519
# epoch 14298: 32051494042
# epoch 14299: 32051463304
# epoch 14300: 31801432566
# epoch 14301: 31801401831
# validator 71734 attester violation at slot 457572 (epoch 14299.4)
# epoch 14297: 32060653435
# epoch 14298: 32060622697
# epoch 14299: 32060591959
# epoch 14300: 31810561221
# epoch 14301: 31810530486
# validator 71744 attester violation at slot 457573 (epoch 14299.5)
# epoch 14297: 32063874425
# epoch 14298: 32063892948
# epoch 14299: 32063862210
# epoch 14300: 31813831472
# epoch 14301: 31813800737
# validator 72081 attester violation at slot 457573 (epoch 14299.5)
# epoch 14297: 32059766349
# epoch 14298: 32059784872
# epoch 14299: 32059754134
# epoch 14300: 31809723396
# epoch 14301: 31809692661
# validator 72082 attester violation at slot 457574 (epoch 14299.6)
# epoch 14297: 32060633168
# epoch 14298: 32060651691
# epoch 14299: 32060620953
# epoch 14300: 31810590215
# epoch 14301: 31810559480
# validator 72493 attester violation at slot 457575 (epoch 14299.7)
# epoch 14297: 32052799447
# epoch 14298: 32052768709
# epoch 14299: 32052737971
# epoch 14300: 31802707233
# epoch 14301: 31802676498
# validator 72496 attester violation at slot 457576 (epoch 14299.8)
# epoch 14297: 32053884389
# epoch 14298: 32053902912
# epoch 14299: 32053872174
# epoch 14300: 31803841436
# epoch 14301: 31803810701
# validator 72503 attester violation at slot 457576 (epoch 14299.8)
# epoch 14297: 32053214841
# epoch 14298: 32053233364
# epoch 14299: 32053202626
# epoch 14300: 31803171888
# epoch 14301: 31803141153
# validator 72508 attester violation at slot 457577 (epoch 14299.9)
# epoch 14297: 32056547097
# epoch 14298: 32056565620
# epoch 14299: 32056534882
# epoch 14300: 31806504144
# epoch 14301: 31806473409
# validator 72511 attester violation at slot 457577 (epoch 14299.9)
# epoch 14297: 32062284973
# epoch 14298: 32062254235
# epoch 14299: 32062223497
# epoch 14300: 31812192759
# epoch 14301: 31812162024
# validator 72807 attester violation at slot 457578 (epoch 14299.10)
# epoch 14297: 32050403764
# epoch 14298: 32050417804
# epoch 14299: 32050387066
# epoch 14300: 31800356328
# epoch 14301: 31800325593
# validator 75045 attester violation at slot 457579 (epoch 14299.11)
# epoch 14297: 32031607209
# epoch 14298: 32031645455
# epoch 14299: 32031614717
# epoch 14300: 31781583979
# epoch 14301: 31781553244
# validator 75172 attester violation at slot 457579 (epoch 14299.11)
# epoch 14297: 32027545722
# epoch 14298: 32027564245
# epoch 14299: 32027533507
# epoch 14300: 31777502769
# epoch 14301: 31777472034
# validator 75204 attester violation at slot 457580 (epoch 14299.12)
# epoch 14297: 32026755566
# epoch 14298: 32026768111
# epoch 14299: 32026737373
# epoch 14300: 31776706635
# epoch 14301: 31776675900
# validator 75212 attester violation at slot 457580 (epoch 14299.12)
# epoch 14297: 32026739637
# epoch 14298: 32026758160
# epoch 14299: 32026727422
# epoch 14300: 31776696684
# epoch 14301: 31776665949
# validator 75711 attester violation at slot 457581 (epoch 14299.13)
# epoch 14297: 32021889869
# epoch 14298: 32021908392
# epoch 14299: 32021877654
# epoch 14300: 31771846916
# epoch 14301: 31771816181
# validator 75723 attester violation at slot 457581 (epoch 14299.13)
# epoch 14297: 32021774356
# epoch 14298: 32021792879
# epoch 14299: 32021762141
# epoch 14300: 31771731403
# epoch 14301: 31771700668
# validator 71743 attester violation at slot 457582 (epoch 14299.14)
# epoch 14297: 32060753959
# epoch 14298: 32060723221
# epoch 14299: 32060692483
# epoch 14300: 31810661745
# epoch 14301: 31810631010
# validator 75699 attester violation at slot 457582 (epoch 14299.14)
# epoch 14297: 32021873000
# epoch 14298: 32021891523
# epoch 14299: 32021860785
# epoch 14300: 31771830047
# epoch 14301: 31771799312
# validator 69873 attester violation at slot 457585 (epoch 14299.17)
# epoch 14297: 32082343908
# epoch 14298: 32082313170
# epoch 14299: 32082282432
# epoch 14300: 31832251694
# epoch 14301: 31832220959
# validator 17395 attester violation at slot 475787 (epoch 14868.11)
# epoch 14866: 32726090906
# epoch 14867: 32726085095
# epoch 14868: 32726103774
# epoch 14869: 32476073462
# epoch 14870: 32476043150
# validator 18989 attester violation at slot 475787 (epoch 14868.11)
# epoch 14866: 32715406099
# epoch 14867: 32715404709
# epoch 14868: 32715423388
# epoch 14869: 32465393076
# epoch 14870: 32465362764
# validator 19001 attester violation at slot 475789 (epoch 14868.13)
# epoch 14866: 32718808342
# epoch 14867: 32718806952
# epoch 14868: 32718776640
# epoch 14869: 32468746328
# epoch 14870: 32468716016
# validator 24696 attester violation at slot 475789 (epoch 14868.13)
# epoch 14866: 32669833354
# epoch 14867: 32669831964
# epoch 14868: 32669801652
# epoch 14869: 32419771340
# epoch 14870: 32419741028
# validator 26278 attester violation at slot 475790 (epoch 14868.14)
# epoch 14866: 32642053349
# epoch 14867: 32642046065
# epoch 14868: 32642064744
# epoch 14869: 32392034432
# epoch 14870: 32392004120
# validator 26201 attester violation at slot 475793 (epoch 14868.17)
# epoch 14866: 32627231210
# epoch 14867: 32627229820
# epoch 14868: 32627248499
# epoch 14869: 32377218187
# epoch 14870: 32377187875
# validator 17164 attester violation at slot 475794 (epoch 14868.18)
# epoch 14866: 32717295169
# epoch 14867: 32717293779
# epoch 14868: 32717308037
# epoch 14869: 32467277725
# epoch 14870: 32467247413
# validator 17228 attester violation at slot 475796 (epoch 14868.20)
# epoch 14866: 32716085720
# epoch 14867: 32716084330
# epoch 14868: 32716054018
# epoch 14869: 32466023706
# epoch 14870: 32465993394
# validator 17304 attester violation at slot 475796 (epoch 14868.20)
# epoch 14866: 32716444387
# epoch 14867: 32716442997
# epoch 14868: 32716461676
# epoch 14869: 32466431364
# epoch 14870: 32466401052
# validator 17140 attester violation at slot 475797 (epoch 14868.21)
# epoch 14866: 32726062586
# epoch 14867: 32726061196
# epoch 14868: 32726079875
# epoch 14869: 32476049563
# epoch 14870: 32476019251
# validator 24703 attester violation at slot 475797 (epoch 14868.21)
# epoch 14866: 32653187348
# epoch 14867: 32653185958
# epoch 14868: 32653204637
# epoch 14869: 32403174325
# epoch 14870: 32403144013
# validator 23179 attester violation at slot 475798 (epoch 14868.22)
# epoch 14866: 32687841463
# epoch 14867: 32687840073
# epoch 14868: 32687858752
# epoch 14869: 32437828440
# epoch 14870: 32437798128
# validator 17291 attester violation at slot 475802 (epoch 14868.26)
# epoch 14866: 32719535717
# epoch 14867: 32719529906
# epoch 14868: 32719542691
# epoch 14869: 32469512379
# epoch 14870: 32469482067
# validator 17189 attester violation at slot 475802 (epoch 14868.26)
# epoch 14866: 32719150145
# epoch 14867: 32719148755
# epoch 14868: 32719118443
# epoch 14869: 32469088131
# epoch 14870: 32469057819
# validator 24528 attester violation at slot 475803 (epoch 14868.27)
# epoch 14866: 32651008529
# epoch 14867: 32651007139
# epoch 14868: 32651021397
# epoch 14869: 32400991085
# epoch 14870: 32400960773
# validator 19017 attester violation at slot 475805 (epoch 14868.29)
# epoch 14866: 32738718636
# epoch 14867: 32738712825
# epoch 14868: 32738682513
# epoch 14869: 32488652201
# epoch 14870: 32488621889
# validator 17232 attester violation at slot 475807 (epoch 14868.31)
# epoch 14866: 32724090538
# epoch 14867: 32724089148
# epoch 14868: 32724107827
# epoch 14869: 32474077515
# epoch 14870: 32474047203
# validator 73292 attester violation at slot 906882 (epoch 28340.2)
# epoch 28338: 32543726726
# epoch 28339: 32543759093
# epoch 28340: 32543791465
# epoch 28341: 32293766220
# epoch 28342: 32293740975
# validator 66420 attester violation at slot 1003554 (epoch 31361.2)
# epoch 31359: 32709200210
# epoch 31360: 32709231931
# epoch 31361: 32709263661
# epoch 31362: 32459238968
# epoch 31363: 32459214275

# %%
# calculate aggregate net rewards (from the change in the balances of active validators)

cursor.execute("SELECT f_balance FROM t_validator_balances WHERE f_epoch = 1 ORDER BY f_validator_index")
prior_balance = cursor.fetchall()
start_time = time.time()
for e, s in enumerate(epoch_summaries):
    if e+2 >= len(epoch_summaries):
        break
    s["aggregate_net_reward"] = 0
    cursor.execute(f"SELECT f_balance FROM t_validator_balances "
                   f"WHERE f_epoch = {e+2} ORDER BY f_validator_index")
    new_balances = cursor.fetchall()
    for validator_index, balance in enumerate(new_balances):
        validator = validators[validator_index]
        if validator
        if validator["activation_epoch"] <= e and (validator["exit_epoch"] > e):
            s["aggregate_net_reward"] += balance[0] - prior_balances[validator_index][0]
    
    prior_balances = new_balances
    print_progress(start_time, e, len(epoch_summaries) - 2)

# %%
# store aggregate net rewards in chaind database

for s in epoch_summaries:
    if "aggregate_net_reward" in s:
        e = s["epoch"]
        anr = s["aggregate_net_reward"]
        cursor.execute(f"INSERT INTO t_epoch_extras (f_epoch, f_aggregate_net_reward) VALUES ({e}, {anr})")

connection.commit()

# %%
# count waiting validators

not_activated_count = 0
for v in validators:
    if v['activation_epoch'] is None:
        not_activated_count += 1
        
not_activated_count

# %%
# get validator status by epoch - waiting, active, exited, slashed
start_time = time.time()

waiting_count = [0] * n_epochs
active_count  = [0] * n_epochs
slashed_count = [0] * n_epochs
exited_count  = [0] * n_epochs

for epoch in range(n_epochs):
    for validator in validators:
        activation_epoch = n_epochs if validator['activation_epoch'] is None else validator['activation_epoch']
        if epoch >= validator['activation_eligibility_epoch'] and epoch < activation_epoch:
            waiting_count[epoch] += 1
        elif validator['exit_epoch'] and epoch >= validator['exit_epoch'] :
            if validator['slashed']:
                slashed_count[epoch] += 1
            else:
                exited_count[epoch] += 1
        elif epoch >= activation_epoch:
            active_count[epoch] += 1

    print_progress(start_time, epoch, n_epochs)

print(f"completed in {elapsed}" + ' ' * 50)       

status_data = pd.DataFrame({'waiting': waiting_count, 'active': active_count,
                            'exited': exited_count, 'slashed': slashed_count})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-a68c35166e25> in <module>
#       2 start_time = time.time()
#       3
# ----> 4 waiting_count = [0] * n_epochs
#       5 active_count  = [0] * n_epochs
#       6 slashed_count = [0] * n_epochs
#
# NameError: name 'n_epochs' is not defined

# %%
# draw validator status stacked area plot
fig=plt.figure(figsize=(12,8))
#plt.stackplot(range(len(status_data.index)), status_data['active'], status_data['slashed'],
#              status_data['exited'], status_data['waiting'],labels=['active','slashed','exited','waiting'],
#              colors=['tab:blue','tab:red','tab:green','tab:orange'])
plt.stackplot(range(2000), status_data['active'].iloc[0:2000], status_data['slashed'].iloc[0:2000],
              status_data['exited'].iloc[0:2000], status_data['waiting'].iloc[0:2000],labels=['active','slashed','exited','waiting'],
              colors=['tab:blue','tab:red','tab:green','tab:orange'])
plt.legend(loc='right')
plt.margins(0,0)
plt.title('Validator status')
plt.xlabel('epoch')
plt.ylabel('number of validators')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-143456d4fda9> in <module>
#       4 #              status_data['exited'], status_data['waiting'],labels=['active','slashed','exited','waiting'],
#       5 #              colors=['tab:blue','tab:red','tab:green','tab:orange'])
# ----> 6 plt.stackplot(range(2000), status_data['active'].iloc[0:2000], status_data['slashed'].iloc[0:2000],
#       7               status_data['exited'].iloc[0:2000], status_data['waiting'].iloc[0:2000],labels=['active','slashed','exited','waiting'],
#       8               colors=['tab:blue','tab:red','tab:green','tab:orange'])
#
# NameError: name 'status_data' is not defined

# %%
# show effective balances

cursor.execute(f"SELECT f_effective_balance FROM t_validator_balances WHERE f_validator_index IN"
               f"(SELECT f_index FROM t_validators WHERE NOT f_slashed  AND f_activation_epoch != -1)"
               f"AND f_epoch = {n_epochs-1}")
eff_balances = pd.Series([b[0]*10**-9 for b in cursor.fetchall()], name='non-slashed')

cursor.execute(f"SELECT f_effective_balance FROM t_validator_balances WHERE f_validator_index IN"
               f"(SELECT f_index FROM t_validators WHERE f_slashed)"
               f"AND f_epoch = {n_epochs-1}")
eff_balances_slashed = pd.Series([b[0]*10**-9 for b in cursor.fetchall()], name='slashed')

print(f"Non-slashed validator balance (min, max): "
      f"({int(eff_balances.min())}, {int(eff_balances.max())}) ETH")
print(f"Slashed validator balance (min, max): "
      f"({int(eff_balances_slashed.min())}, {int(eff_balances_slashed.max())}) ETH")

cursor.execute(f"SELECT COUNT(*) FROM t_validator_balances WHERE f_validator_index IN "
               f"(SELECT f_index FROM t_validators WHERE NOT f_slashed AND f_activation_epoch != -1 "
               f"AND f_effective_balance < 32000000000) AND f_epoch = {n_epochs-1}")
n_reduced_balance = cursor.fetchone()[0]

cursor.execute("SELECT COUNT(*) FROM t_validators WHERE NOT f_slashed AND f_activation_epoch != -1")
n_not_slashed = cursor.fetchone()[0]

print(f"{n_reduced_balance} non-slashed validators have an effective balance of less than 32 ETH "
      f"({100 * n_reduced_balance / n_not_slashed:.2f}% of non-slashed validators)")
